# %%
pip install transformers datasets accelerate sentencepiece protobuf
# Out:
# ...
#   Using cached setuptools-82.0.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.4 MB 1.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/10.4 MB 1.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/10.4 MB 1.5 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/10.4 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/10.4 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/10.4 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/10.4 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/10.4 MB 1.5 MB/s eta 0:00:06
#    --------- ------------------------------ 2.4/10.4 MB 1.1 MB/s eta 0:00:08
# ...
